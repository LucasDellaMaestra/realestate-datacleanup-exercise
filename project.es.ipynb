# %% [markdown]
# # Limpieza de bienes raíces
#
# Este es un conjunto de datos (dataset) reales que fue descargado usando técnicas de web scraping. La data contiene registros de **Fotocasa**, el cual es uno de los sitios más populares de bienes raíces en España. Por favor no hagas esto (web scraping) a no ser que sea para propósitos académicos.
#
# El dataset fue descargado hace algunos años por Henry Navarro y en ningún caso se obtuvo beneficio económico de ello.
#
# Contiene miles de datos de casas reales publicadas en la web www.fotocasa.com. Tu objetivo es extraer tanta información como sea posible con el conocimiento que tienes hasta ahora de ciencia de datos, por ejemplo ¿cuál es la casa más cara en todo el dataset?
#
# Empecemos precisamente con esa pregunta... ¡Buena suerte!

# %% [markdown]
# #### Ejercicio 00. Lee el dataset assets/real_estate.csv e intenta visualizar la tabla (★☆☆)

# %%
import pandas as pd

# Este archivo CSV contiene puntos y comas en lugar de comas como separadores
ds = pd.read_csv('assets/real_estate.csv', sep=';')
ds
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# #### Ejercicio 01. ¿Cuál es la casa más cara en todo el dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle del Prado, Nº20 es la más cara y su precio es de 5000000 USD`

# %%
# defino cual va ser la columna a analizar
precio= 'price'
#busco el indice con el valor del precio mas alto
N_de_casa= ds[precio].idxmax()
#utilizo ese indice para localizar la columna de la direccion
direccion= ds.loc[N_de_casa, 'address']
#busco cual es el precio mas alto
precio_max=ds[precio].max()
#imprimo el resultado

print("la casa con direccion en ", direccion, "N° ", N_de_casa, "es la mas cara y su precio es de ", precio_max, "USd")
# Out:
# la casa con direccion en  El Escorial N°  13110 es la mas cara y su precio es de  8500000 USd

# %% [markdown]
# #### Ejercicio 02. ¿Cuál es la casa más barata del dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle Alcalá, Nº58 es la más barata y su precio es de 12000 USD`

# %%
# defino cual va ser la columna a analizar
precio= 'price'
#busco el indice con el valor del precio mas bajo
N_de_casa2= ds[precio].idxmin()
#utilizo ese indice para localizar la columna de la direccion
direccion_min= ds.loc[N_de_casa2, 'address']
#busco cual es el precio mas bajo
precio_min=ds[precio].min()
#imprimo el resultado

print("la casa con direccion en ", direccion_min, "N° ", N_de_casa2, "es la mas barata y su precio es de ", precio_min, "USd")
# Out:
# la casa con direccion en  Parla N°  366 es la mas barata y su precio es de  0 USd

# %% [markdown]
# #### Ejercicio 03. ¿Cuál es la casa más grande y la más pequeña del dataset? (★☆☆)
#
# Imprime la dirección y el área de las casas seleccionadas. Por ejemplo:
#
# `La casa más grande está ubicada en Calle Gran Vía, Nº38 y su superficie es de 5000 metros`
#
# `La casa más pequeña está ubicada en Calle Mayor, Nº12 y su superficie es de 200 metros`

# %%
#defino la columna a analizar
superficie='surface'
#busco el indice asociado a la superficie mas grande
indx_sup_max= ds[superficie].idxmax()
#busco el indice asociado a la superficie mas pequeña
indx_sup_min= ds[superficie].idxmin()
#con los indices buscados los uso para encontrar el nombre de la calle de cada casa
casa_sup_max= ds.loc[indx_sup_max, 'address']
casa_sup_min= ds.loc [indx_sup_min, 'address']
#busco la superfcie mas grande y mas pequeña del dataset
sup_max= ds[superficie].max()
sup_min= ds[superficie].min()

#imprimo ambos resultados
print("la casa mas grande esta ubicada en ", casa_sup_max, ", N° ", indx_sup_max, "y su superficie es de ", sup_max, "metros")
print("la casa mas pequeña esta ubicada en ", casa_sup_min, ", N° ", indx_sup_min, "y su superficie es de ", sup_min, "metros")
# Out:
# la casa mas grande esta ubicada en  Sevilla la Nueva , N°  6794 y su superficie es de  249000.0 metros
# la casa mas pequeña esta ubicada en  Calle Amparo,  Madrid Capital , N°  498 y su superficie es de  15.0 metros

# %% [markdown]
# #### Ejercicio 04. ¿Cuantas poblaciones (columna level5) contiene el dataset? (★☆☆)
#
# Imprime el nombre de las poblaciones separadas por coma. Por ejemplo:
#
# `> print(populations)`
#
# `population1, population2, population3, ...`

# %%
#busco las poblaciones del dataset que no se repiten
populations= ds['level5'].unique()
#imprimo el resultado
print (populations)
# Out:
# ['Arganda del Rey' 'Fuenlabrada' 'Boadilla del Monte'
#  'Las Rozas de Madrid' ' Madrid Capital' 'Villaviciosa de Odón' 'Pinto'
#  'Valdemoro' 'Navalcarnero' 'Pozuelo de Alarcón' 'Torrejón de Ardoz'
#  'Navalagamella' 'San Sebastián de los Reyes' 'Rivas-vaciamadrid'
#  'Alpedrete' 'Móstoles' 'San Fernando de Henares' 'Coslada'
#  'Becerril de la Sierra' 'Alcalá de Henares' 'Chinchón' 'Parla' 'Alcorcón'
#  'El Escorial' 'Leganés' 'Pedrezuela' 'Majadahonda'
#  'Villanueva de la Cañada' 'Villanueva del Pardillo' 'Torrelodones'
#  'Moralzarzal' 'Mejorada del Campo' 'Aranjuez' 'Corpa' 'Getafe'
#  'Velilla de San Antonio' 'Sevilla la Nueva' 'San Martín de la Vega'
#  'Villalbilla' 'Collado Villalba' 'Alcobendas' 'El Molar (Madrid)'
#  'Moraleja de Enmedio' 'Algete' 'Campo Real' 'Torrejón de la Calzada'
#  'Colmenar Viejo' 'Valdemorillo' 'Fuente El Saz de Jarama' 'Tres Cantos'
#  'Arroyomolinos (Madrid)' 'Griñón' 'Paracuellos de Jarama' 'Guadarrama'
# ...

# %% [markdown]
# #### Ejercicio 05. ¿El dataset contiene valores no admitidos (NAs)? (★☆☆)
#
# Imprima un booleano (`True` o `False`) seguido de la fila/columna que contiene el NAs.

# %%
# para saber si el dataset tiene valores no admitidos utilizo la funcion isnull()

#imprimo el nuevo dataset

print (ds.isnull())
# Out:
#        Unnamed: 0  id_realEstates  isNew  realEstate_name  phone_realEstate  \
# 0           False           False  False            False             False
# 1           False           False  False            False             False
# 2           False           False  False            False             False
# 3           False           False  False            False             False
# 4           False           False  False            False             False
# ...           ...             ...    ...              ...               ...
# 15330       False           False  False            False             False
# 15331       False           False  False            False             False
# 15332       False           False  False            False             False
# 15333       False           False  False            False             False
# 15334       False           False  False            False             False
#
# ...

# %% [markdown]
# #### Ejercicio 06. Elimina los NAs del dataset, si aplica (★★☆)
#
# Imprima una comparación entre las dimensiones del DataFrame original versus el DataFrame después de las eliminaciones.

# %% [markdown]
# #### Ejercicio 07. ¿Cuál la media de precios en la población (columna level5) de "Arroyomolinos (Madrid)"? (★★☆)
#
# Imprima el valor obtenido.

# %%
# defino las columas que quiero analizar
poblacion= 'level5'
precio='price'
#calculo la media de la poblacion para el valor determinado Arroyomolino (Madrid)
media_precio= ds.groupby(poblacion)[precio].mean()

print("la media de precio para la region de Arroyomolinoes (Madrid) es de ",media_precio["Arroyomolinos (Madrid)"])
# Out:
# la media de precio para la region de Arroyomolinoes (Madrid) es de  294541.59854014596

# %% [markdown]
# #### Ejercicio 08. Trazar el histograma de los precios para la población (level5 column) de "Arroyomolinos (Madrid)" y explica qué observas (★★☆)
#
# Imprime el histograma de los precios y escribe en la celda del Markdown un breve análisis del trazado.

# %%
import matplotlib.pyplot as plt

ds_arroyomolino=ds[ds[poblacion]=="Arroyomolinos (Madrid)"]

#trazo el histograma de los precios para ese dataframe filtrado

plt.hist(ds_arroyomolino[precio], bins=10, alpha=0.7)

#agrego titulo y etiquetas

plt.title("histograma de " + precio + "para " + "Arroyomolinos (Madrid)")

plt.xlabel(precio)
plt.ylabel ("Frecuencia")

plt.show()

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, haz doble clic en esta celda, elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 09. ¿Son los precios promedios de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios y escribe una conclusión sobre ellos.

# %%
# calculo el promedio de Valdemorillo y Galapagar
media_valdemorillo= media_precio["Valdemorillo"]
media_galapagar= media_precio["Galapagar"]
print (media_valdemorillo)
print(media_galapagar)
if media_galapagar==media_valdemorillo:
    print ("los precios promedios de Valdemorillo y Galapagar son iguales")
else: print ("Los precios promedios de Valdemorillo y Galapagar son distintos")
# Out:
# 363860.2931034483
# 360063.20238095237
# Los precios promedios de Valdemorillo y Galapagar son distintos

# %% [markdown]
# #### Ejercicio 10. ¿Son los promedios de precio por metro cuadrado (precio/m2) de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios de precio por metro cuadrado y escribe una conclusión sobre ellos.
#
# Pista: Crea una nueva columna llamada `pps` (*price per square* o precio por metro cuadrado) y luego analiza los valores.

# %%
# creo una nueva columna que haga la relacion de precio por metro cuadrado

ds["pps"]=ds[precio]/ds[superficie]
#calculo la media de precio por metro cuadrado
media_pps= ds.groupby(poblacion)["pps"].mean()

#calculo la media para cada poblacion indicada
media_pps_galapagar=media_pps["Galapagar"]
media_pps_valdemorillo=media_pps["Valdemorillo"]
print (media_pps_galapagar)
print(media_pps_valdemorillo)
if media_galapagar==media_valdemorillo:
    print ("el precio por metro cuadrado promedio de Valdemorillo y Galapagar son iguales")
else: print ("el precio por metro cuadrado promedio de Valdemorillo y Galapagar son distintos")
# Out:
# 1606.3240303094024
# 1317.9502109024984
# el precio por metro cuadrado promedio de Valdemorillo y Galapagar son distintos

# %% [markdown]
# #### Ejercicio 11. Analiza la relación entre la superficie y el precio de las casas. (★★☆)
#
# Pista: Puedes hacer un `scatter plot` y luego escribir una conclusión al respecto.

# %%
#selecciono las dos columnas a analizar
x=ds[precio]
y=ds[superficie]

plt.scatter(x,y)
plt.xlabel("precio")
plt.ylabel("superficie")
plt.title("relacion precio/superficie")

plt.show()

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, haz doble clic en esta celda, elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 12. ¿Cuántas agencia de bienes raíces contiene el dataset? (★★☆)
#
# Imprime el valor obtenido.

# %%
nombres_agencias= ds["realEstate_name"].unique()
valores_agencias=len(nombres_agencias)

print ("el dataset contiene ", valores_agencias, "agencias de bienes raices.")
# Out:
# el dataset contiene  1822 agencias de bienes raices.

# %% [markdown]
# #### Ejercicio 13. ¿Cuál es la población (columna level5) que contiene la mayor cantidad de casas?(★★☆)
#
# Imprima la población y el número de casas.

# %%
poblaciones=ds[poblacion]

mayor_poblacion= poblaciones.value_counts().idxmax()
mayor_poblacion_numero= len(mayor_poblacion)
print ("el valor de poblacion que contiene mas casas es ", mayor_poblacion, ", y tiene ", mayor_poblacion_numero, "casas")
# Out:
# el valor de poblacion que contiene mas casas es   Madrid Capital , y tiene  15 casas

# %% [markdown]
# #### Ejercicio 14. Ahora vamos a trabajar con el "cinturón sur" de Madrid. Haz un subconjunto del DataFrame original que contenga las siguientes poblaciones (columna level5): "Fuenlabrada", "Leganés", "Getafe", "Alcorcón" (★★☆)
#
# Pista: Filtra el DataFrame original usando la columna `level5` y la función `isin`.

# %%
cinturon_sur=["Fuenlabrada","Getafe","Alcorcón","Leganés"]
ds_cinturon_sur= ds[ds[poblacion].isin(cinturon_sur)]

ds_cinturon_sur
# Out:
#        Unnamed: 0  id_realEstates  isNew  \
# 1               2       153867863  False
# 3               4       152776331  False
# 85             86       153152077  False
# 94             95       153995577  False
# 109           110       153586414  False
# ...           ...             ...    ...
# 15275       15276       153903887  False
# 15291       15292       151697757  False
# 15305       15306       153902389  False
# 15322       15323       153871864  False
# 15325       15326       153901467  False
#
#                                  realEstate_name  phone_realEstate  \
# 1              tecnocasa fuenlabrada ferrocarril       916358736.0
# 3              tecnocasa fuenlabrada ferrocarril       916358736.0
# 85                       sinergical inmobiliaria               NaN
# 94                               viviendas365com       911226014.0
# 109              area uno asesores inmobiliarios       912664081.0
# ...

# %% [markdown]
# #### Ejercicio 15. Traza un gráfico de barras de la mediana de los precios y explica lo que observas (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprima un gráfico de barras de la mediana de precios y escriba en la celda Markdown un breve análisis sobre el gráfico.

# %%
# calculo la mediana de los precios para cada grupo
mediana_cinturon_sur= ds_cinturon_sur.groupby(poblacion)[precio].median()
#trazo el grafico de barras para la mediana
mediana_cinturon_sur.plot(kind="bar", title="Mediana de precios para cinturon sur")
plt.xlabel("poblaciones")
plt.ylabel("precios")

plt.show()

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, haz doble clic en esta celda, elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 16. Calcula la media y la varianza de muestra para las siguientes variables: precio, habitaciones, superficie y baños (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprime ambos valores por cada variable.

# %%
# Calculo la media y varianza para la columna precio
media_precio_cinturon_sur= ds_cinturon_sur[precio].mean()
varianza_precio_cinturon_sur= ds_cinturon_sur[precio].var()

print("la media de precios para el cinturon sur es de ", media_precio_cinturon_sur, "y su varianza es de ", varianza_precio_cinturon_sur)

# Calculo la media y varianza para la columna habitacion
media_habitacion_cinturon_sur= ds_cinturon_sur["rooms"].mean()
varianza_habitacion_cinturon_sur= ds_cinturon_sur["rooms"].var()

print("la media de habitaciones para el cinturon sur es de ", media_habitacion_cinturon_sur, "y su varianza es de ", varianza_habitacion_cinturon_sur)

# Calculo la media y varianza para la columna superficie
media_superficie_cinturon_sur= ds_cinturon_sur[superficie].mean()
varianza_superficie_cinturon_sur= ds_cinturon_sur[superficie].var()

print("la media de superficie para el cinturon sur es de ", media_superficie_cinturon_sur, "y su varianza es de ", varianza_superficie_cinturon_sur)

# Calculo la media y varianza para la columna baños
media_baños_cinturon_sur= ds_cinturon_sur["bathrooms"].mean()
varianza_baños_cinturon_sur= ds_cinturon_sur["bathrooms"].var()

print("la media de baños para el cinturon sur es de ", media_baños_cinturon_sur, "y su varianza es de ", varianza_baños_cinturon_sur)
# Out:
# la media de precios para el cinturon sur es de  223094.48070562293 y su varianza es de  14921367508.04902
# la media de habitaciones para el cinturon sur es de  3.0177383592017737 y su varianza es de  0.7188858892927542
# la media de superficie para el cinturon sur es de  111.75222363405337 y su varianza es de  4263.051760316337
# la media de baños para el cinturon sur es de  1.633221850613155 y su varianza es de  0.5717968625577321

# %% [markdown]
# #### Ejercicio 17. ¿Cuál es la casa más cara de cada población? Debes usar el subset obtenido en la pregunta 14 (★★☆)
#
# Imprime tanto la dirección como el precio de la casa seleccionada de cada población. Puedes imprimir un DataFrame o una sola línea para cada población.

# %%
ds_precio_max=ds_cinturon_sur.groupby(poblacion)[precio].max().reset_index()

ds_precio_max
# Out:
#         level5    price
# 0     Alcorcón   950000
# 1  Fuenlabrada   490000
# 2       Getafe  1050000
# 3      Leganés   650000

# %% [markdown]
# #### Ejercicio 18. Normaliza la variable de precios para cada población y traza los 4 histogramas en el mismo gráfico (debes usar el subconjunto obtenido en la pregunta 14) (★★★)
#
# Para el método de normalización, puedes usar el que consideres adecuado, no hay una única respuesta correcta para esta pregunta. Imprime el gráfico y escribe en la celda de Markdown un breve análisis sobre el gráfico.
#
# Pista: Puedes ayudarte revisando la demostración multihist de Matplotlib.

# %%
ds_normalizado=ds_cinturon_sur.groupby(poblacion)[precio].apply(lambda x:(x- x.min())/(x.max()-x.min()))
ds_normalizado=ds_normalizado.reset_index()
del ds_normalizado["level_1"]

ds_normalizado

fig, axs=plt.subplots(2,2,figsize=(10,8))

for i, valor in enumerate(ds_normalizado[poblacion].unique()) :
    datos=ds_normalizado[ds_normalizado[poblacion]== valor][precio]
    axs[i//2,i%2].hist(datos,bins=50)
    axs[i//2,i%2].set_title(f"histograma para {valor}")

fig.tight_layout()

plt.show()

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, haz doble clic en esta celda, elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 19. ¿Qué puedes decir sobre el precio por metro cuadrado (precio/m2) entre los municipios de 'Getafe' y 'Alcorcón'? Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
#
# Pista: Crea una nueva columna llamada `pps` (price per square en inglés) y luego analiza los valores

# %%
#la columna de pps ya esta dentro del DataFrame del cinturón sur
#analizo los municipios seleccionados

precio_por_metro= ds_cinturon_sur.groupby(poblacion)["pps"].mean()
prom_pps_get=precio_por_metro["Getafe"]
prom_pps_alco=precio_por_metro["Alcorcón"]

if prom_pps_get==prom_pps_alco:
    print ("los promedios de precio por metro entre las dos regiones son iguales")
else: print ("los promedios entre las dos regiones son distintos")
# Out:
# los promedios entre las dos regiones son distintos

# %% [markdown]
# #### Ejercicio 20. Realiza el mismo gráfico para 4 poblaciones diferentes (columna level5) y colócalos en el mismo gráfico. Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
# Pista: Haz un diagrama de dispersión de cada población usando subgráficos (subplots).

# %%
# TODO

# %% [markdown]
# #### Ejercicio 21. Realiza un trazado de las coordenadas (columnas latitud y longitud) del cinturón sur de Madrid por color de cada población (debes usar el subconjunto obtenido del Ejercicio 14) (★★★★)
#
# Ejecuta la siguiente celda y luego comienza a codear en la siguiente. Debes implementar un código simple que transforme las columnas de coordenadas en un diccionario de Python (agrega más información si es necesario) y agrégala al mapa.

# %%
from ipyleaflet import Map, basemaps

# Mapa centrado en (60 grados latitud y -2.2 grados longitud)
# Latitud, longitud
map = Map(center = (60, -2.2), zoom = 2, min_zoom = 1, max_zoom = 20, 
    basemap=basemaps.Stamen.Terrain)
map
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.11/site-packages/xyzservices/lib.py:45, in Bunch.__getattr__(self, key)
#      44 try:
# ---> 45     return self.__getitem__(key)
#      46 except KeyError as err:
#
# KeyError: 'Stamen'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[49], line 6
#       1 from ipyleaflet import Map, basemaps
#       3 # Mapa centrado en (60 grados latitud y -2.2 grados longitud)
#       4 # Latitud, longitud
#       5 map = Map(center = (60, -2.2), zoom = 2, min_zoom = 1, max_zoom = 20,
# ----> 6     basemap=basemaps.Stamen.Terrain)
#       7 map
#
# File ~/.local/lib/python3.11/site-packages/xyzservices/lib.py:47, in Bunch.__getattr__(self, key)
#      45     return self.__getitem__(key)
# ...

# %%
## Aquí: traza la coordenadas de los estados

## PON TU CÓDIGO AQUÍ:
